# %%
import pandas as pd
import IPython.display as ipd

max_corrs = pd.read_csv('max_correlations.csv').drop('Unnamed: 0', axis=1) #remove unnamed column which is added as the frame did not have an index when saved
#this shows the most highly correlated factor or predicted risk value for each factor
ipd.display(max_corrs)

factors_data = pd.read_csv('factors_data.csv').set_index('personId')
print(factors_data.sum())
#shows how many positive results for each factor (i.e. how many patients have experienced the factor)

print('The most commonly exerienced factors are:')
print(factors_data.sum().loc[factors_data.sum() >= 20])
#these represent the most commonly experienced factors in the prior year
# Out:
#                                       Factor  \
# 0      Acetaminophen exposures in prior year
# 1     Occurrence of Alcoholism in prior year
# 2                       Anemia in prior year
# 3                Angina events in prior year
# 4               ANTIEPILEPTICS in prior year
# ..                                       ...
# 59    Antibiotics Polypeptides in prior year
# 60      Antibiotics Rifamycins in prior year
# 61    Antibiotics Sulfonamides in prior year
# 62  Antibiotics Streptogramins in prior year
# 63   Antibiotics Tetracyclines in prior year
#
#    Strongest correlation (factors and predicted risk)  \
# 0      Urinary tract infectious disease in prior year
# 1            Antibiotics Oxazolidinones in prior year
# 2                predicted risk of Pulmonary Embolism
# 3   Type 1 diabetes and no prior specific non-T1DM...
# 4             predicted risk of Restless Leg Syndrome
# ..                                                ...
# 59                 Heart valve disorder in prior year
# 60              Antibiotics Penicillins in prior year
# 61                    Aspirin exposures in prior year
# 62     Urinary tract infectious disease in prior year
# 63  predicted risk of  Treatment resistant depress...
#
#           Strongest correlation (predicted risk only)
# 0             predicted risk of Restless Leg Syndrome
# 1   predicted risk of  Treatment resistant depress...
# 2                predicted risk of Pulmonary Embolism
# 3                predicted risk of Multiple Sclerosis
# 4             predicted risk of Restless Leg Syndrome
# ..                                                ...
# 59  predicted risk of Acute pancreatitis, with No ...
# 60        predicted risk of Muscle weakness or injury
# 61               predicted risk of Ulcerative colitis
# 62           predicted risk of Ankylosing Spondylitis
# 63  predicted risk of  Treatment resistant depress...
#
# [64 rows x 3 columns]
# Acetaminophen exposures in prior year        8
# Occurrence of Alcoholism in prior year      12
# Anemia in prior year                        18
# Angina events in prior year                 13
# ANTIEPILEPTICS in prior year                15
#                                             ..
# Antibiotics Polypeptides in prior year      16
# Antibiotics Rifamycins in prior year        20
# Antibiotics Sulfonamides in prior year      19
# Antibiotics Streptogramins in prior year    16
# Antibiotics Tetracyclines in prior year      9
# Length: 64, dtype: int64
# The most commonly exerienced factors are:
# Atrial Fibrillation, incident in prior year    20
# Heart failure in prior year                    24
# Deep Vein Thrombosis (DVT) in prior year       21
# Inflammatory Bowel Disease in prior year       21
# Occurrence of neuropathy in prior year         20
# Psychotic disorder in prior year               21
# Antibiotics Rifamycins in prior year           20
# dtype: int64
